# %%
import os
os.chdir("C:\\Users\\nagaa\\Desktop\\ABHI\\COURSES\\256chang\\Book-Recommendation-System")

print(os.getcwd())
# Out:
# C:\Users\nagaa\Desktop\ABHI\COURSES\256chang\Book-Recommendation-System

# %%
import requests
import bs4
import re
import numpy as np
import pandas as pd

# %%
page1 = 'https://www.goodreads.com/genres/list?page=1'
page2 = 'https://www.goodreads.com/genres/list?page=2'
page3 = 'https://www.goodreads.com/genres/list?page=3'
page4 = 'https://www.goodreads.com/genres/list?page=4'
page5 = 'https://www.goodreads.com/genres/list?page=5'

# %%
req1, req2, req3, req4, req5 = [requests.get(page)
                                for page in [page1, page2, page3, page4, page5]]

# %%
soup1, soup2, soup3, soup4, soup5 = [bs4.BeautifulSoup(page.text, "lxml")
                                    for page in [req1, req2, req3, req4, req5] ]

# %%
soup1
# Out:
# <!DOCTYPE html>
# <html class="desktop">
# <head>
# <title>Genre shelves</title>
# <meta content="Genres on Goodreads. Browse books by 10th-century, 11th-century, 12th-century, 13th-century, 14th-century, 15th-century, 16th-century, 17th-century, 1864..." name="description"/>
# <meta content="telephone=no" name="format-detection"/>
# <script type="text/javascript">
#         if (window.Mobvious === undefined) {
#           window.Mobvious = {};
#         }
#         window.Mobvious.device_type = 'desktop';
#         </script>
# <script src="https://s.gr-assets.com/assets/webfontloader-d1c43fc04f3369977d0513c94df0a504.js"></script>
# <script>
# //<![CDATA[
#
#   WebFont.load({
#     classes: false,
#     custom: {
#       families: ["Lato:n4,n7,i4", "Merriweather:n4,n7,i4"],
#       urls: ["https://s.gr-assets.com/assets/gr/fonts-e256f84093cc13b27f5b82343398031a.css"]
#     }
#   });
#
# //]]>
# </script>
# <link href="https://s.gr-assets.com/assets/goodreads-ca0f9bddd9a36f152221a7c412c25e3b.css" media="all" rel="stylesheet"/>
# <link href="https://s.gr-assets.com/assets/common_images-670d97636259cafc355c94fc43e871d7.css" media="screen" rel="stylesheet"/>
# <script src="https://s.gr-assets.com/assets/desktop/libraries-66d94f0e16192d36d665cef61079399b.js"></script>
# <script src="https://s.gr-assets.com/assets/application-c0a09a8474985b94acd20bfac2540b5e.js"></script>
# <script>
#   //<![CDATA[
#     var gptAdSlots = gptAdSlots || [];
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     (function() {
#       var gads = document.createElement("script");
#       gads.async = true;
#       gads.type = "text/javascript";
#       var useSSL = "https:" == document.location.protocol;
#       gads.src = (useSSL ? "https:" : "http:") +
#       "//securepubads.g.doubleclick.net/tag/js/gpt.js";
#       var node = document.getElementsByTagName("script")[0];
#       node.parentNode.insertBefore(gads, node);
#     })();
#     // page settings
#   //]]>
# </script>
# <script>
#   //<![CDATA[
#     googletag.cmd.push(function() {
#       googletag.pubads().setTargeting("sid", "osid.f5738959b9dfd37bc6f3a00832d361c8");
#     googletag.pubads().setTargeting("grsession", "osid.f5738959b9dfd37bc6f3a00832d361c8");
#     googletag.pubads().setTargeting("surface", "desktop");
#     googletag.pubads().setTargeting("signedin", "false");
#     googletag.pubads().setTargeting("gr_author", "false");
#     googletag.pubads().setTargeting("author", []);
#       googletag.pubads().enableAsyncRendering();
#       googletag.pubads().enableSingleRequest();
#       googletag.pubads().collapseEmptyDivs(true);
#       googletag.pubads().disableInitialLoad();
#       googletag.enableServices();
#     });
#   //]]>
# </script>
# <script>
#   //<![CDATA[
#     ! function(a9, a, p, s, t, A, g) {
#       if (a[a9]) return;
#
#       function q(c, r) {
#         a[a9]._Q.push([c, r])
#       }
#       a[a9] = {
#       init: function() {
#         q("i", arguments)
#       },
#       fetchBids: function() {
#         q("f", arguments)
#       },
#       setDisplayBids: function() {},
#         _Q: []
#       };
#       A = p.createElement(s);
#       A.async = !0;
#       A.src = t;
#       g = p.getElementsByTagName(s)[0];
#       g.parentNode.insertBefore(A, g)
#     }("apstag", window, document, "script", "//c.amazon-adsystem.com/aax2/apstag.js");
#
#     apstag.init({
#       pubID: '3211', adServer: 'googletag', bidTimeout: 4e3
#     });
#   //]]>
# </script>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="kOD775sSGy7ukHgMvF9kDMbaGmoMhyDr++gI0/UDfkOBwNjhv7VEw1+G0uDbVv4LkVj4IaeRk1+Meewvarkr5g==" name="csrf-token"/>
# <meta content="T3KSVVZAX41FFNC1Z4VF" name="request-id"/>
# <script defer="defer" src="https://s.gr-assets.com/assets/react_client_side/external_dependencies-1173133845.js"></script>
# <script defer="defer" src="https://s.gr-assets.com/assets/react_client_side/site_header-7726a97c9e.js"></script>
# <script defer="defer" src="https://s.gr-assets.com/assets/react_client_side/custom_react_ujs-379f5320de9e2c93a9362d21a73b8066.js"></script>
# <link href="/opensearch.xml" rel="search" title="Goodreads" type="application/opensearchdescription+xml"/>
# <script>
# //<![CDATA[
#
#   var GoodreadsAnalytics = GoodreadsAnalytics || {};
#   var _gaq = _gaq || [];
#
#   GoodreadsAnalytics.push = function () {
#     _gaq.push.apply(_gaq, arguments);
#   }
#
#   GoodreadsAnalytics.push(['_setAccount', 'UA-968618-1']);
#   GoodreadsAnalytics.push(['_setCustomVar',
#     1,                        // Slot 1
#     'User Status',            // Custom variable name
#     'signed_out',  // Custom variable value: signed_out, signed_in,
#                               //   signed_in_facebook_connected, or
#                               //   goodreads_member_previously_signed_in
#     2                         // Visit-level scope, which means slot 1 will be
#                               //   free when the visit ends.
#   ]);
#   GoodreadsAnalytics.push(['_setCustomVar',
#     2,                        // Slot 2
#     'Device Type',            // Custom variable name
#     'desktop',         // Custom variable value: desktop, mobile, or
#                               //   tablet
#     2                         // Visit-level scope, which means slot 2 will be
#                               //   free when the visit ends.
#   ]);
#   GoodreadsAnalytics.push(['_trackPageview']);
#
#   (function () {
#     var ga = document.createElement('script');
#     ga.type = 'text/javascript';
#     ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(ga, s);
#   })();
#
# //]]>
# </script>
# <meta content="Genres on Goodreads. Browse books by 10th-century, 11th-century, 12th-century, 13th-century, 14th-century, 15th-century, 16th-century, 17th-century, 1864..." name="description"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@goodreads" name="twitter:site"/>
# <meta content="Genre shelves" name="twitter:title"/>
# <meta content="Genres on Goodreads. Browse books by 10th-century, 11th-century, 12th-century, 13th-century, 14th-century, 15th-century, 16th-century, 17th-century, 1864..." name="twitter:description"/>
# <meta content="cEf8XOH0pulh1aYQeZ1gkXHsQ3dMPSyIGGYqmF53690=" name="verify-v1"/>
# <meta content="PfFjeZ9OK1RrUrKlmAPn_iZJ_vgHaZO1YQ-QlG2VsJs" name="google-site-verification"/>
# <meta content="app-id=355833469" name="apple-itunes-app"/>
# </head>
# <body class="">
# <div class="content">
# <script>
#   //<![CDATA[
#     var initializeGrfb = function() {
#       $grfb.initialize({
#         appId: "2415071772",
#         grSession: false,
#         serverFBUser: null,
#         suppressAutoLogin: false
#       });
#     };
#     if (typeof $grfb !== "undefined") {
#       initializeGrfb();
#     } else {
#       window.addEventListener("DOMContentLoaded", function() {
#         if (typeof $grfb !== "undefined") {
#           initializeGrfb();
#         }
#       });
#     }
#   //]]>
# </script>
# <div class="siteHeader">
# <div data-react-class="ReactComponents.HeaderStoreConnector" data-react-props='{"myBooksUrl":"/review/list","browseUrl":"/book","recommendationsUrl":"/recommendations","choiceAwardsUrl":"/choiceawards","genresIndexUrl":"/genres","giveawayUrl":"/giveaway","homeUrl":"/","listUrl":"/list","blogUrl":"/blog/index","editorsPicksUrl":"/voice","newsUrl":"/news","communityUrl":"/group","groupsUrl":"/group","quotesUrl":"/quotes","featuredAskAuthorUrl":"/ask_the_author","searchPath":"/search","discussionsUrl":"/topic","autocompleteUrl":"/book/auto_complete","defaultLogoActionUrl":"/","logoActionUrl":"/","readingNotesUrl":"/notes?ref=nd","topFullImage":{"topFullImageUrl":"/blog/show/1652?int=sffweek_eb","topFullImageAlt":"Goodreads SciFi Week 2019","xs":{"1x":"https://s.gr-assets.com/assets/site_header/editorial_top_full_xs_1x_scifiweek_2019-dc568a41ce1c36b4f601a0d4914f1ee9.jpg","2x":"https://s.gr-assets.com/assets/site_header/editorial_top_full_xs_2x_scifiweek_2019-dc568a41ce1c36b4f601a0d4914f1ee9.jpg"},"md":{"1x":"https://s.gr-assets.com/assets/site_header/editorial_top_full_md_1x_scifiweek_2019-633fa81575b42c0aabe43bd6633e2476.jpg","2x":"https://s.gr-assets.com/assets/site_header/editorial_top_full_md_2x_scifiweek_2019-633fa81575b42c0aabe43bd6633e2476.jpg"}},"newReleasesUrl":"/book/popular_by_date/2019/8","signInUrl":"/user/sign_in","signUpUrl":"/user/sign_up","signInWithReturnUrl":true,"deployServices":["nav_bar_discussions_pane"],"defaultLogoAltText":"Goodreads Home","logoAltText":"Goodreads Home","mobviousDeviceType":"desktop"}'><header data-react-checksum="-2140343403" data-reactid=".eynpw4eznk"><div class="siteHeader__topLine gr-box gr-box--withShadow" data-reactid=".eynpw4eznk.1"><div class="siteHeader__contents" data-reactid=".eynpw4eznk.1.0"><div class="siteHeader__topLevelItem siteHeader__topLevelItem--searchIcon" data-reactid=".eynpw4eznk.1.0.0"><button aria-label="Toggle search" class="siteHeader__searchIcon gr-iconButton" data-reactid=".eynpw4eznk.1.0.0.0" data-ux-click="true" type="button"></button></div><a aria-label="Goodreads Home" class="siteHeader__logo" data-reactid=".eynpw4eznk.1.0.2" href="/" title="Goodreads Home"></a><nav class="siteHeader__primaryNavInline" data-reactid=".eynpw4eznk.1.0.3"><ul class="siteHeader__menuList" data-reactid=".eynpw4eznk.1.0.3.0" role="menu"><li class="siteHeader__topLevelItem siteHeader__topLevelItem--home" data-reactid=".eynpw4eznk.1.0.3.0.0"><a class="siteHeader__topLevelLink" data-reactid=".eynpw4eznk.1.0.3.0.0.0" href="/">Home</a></li><li class="siteHeader__topLevelItem" data-reactid=".eynpw4eznk.1.0.3.0.1"><a class="siteHeader__topLevelLink" data-reactid=".eynpw4eznk.1.0.3.0.1.0" href="/review/list">My Books</a></li><li class="siteHeader__topLevelItem" data-reactid=".eynpw4eznk.1.0.3.0.2"><div class="primaryNavMenu primaryNavMenu--siteHeaderBrowseMenu ignore-react-onclickoutside" data-reactid=".eynpw4eznk.1.0.3.0.2.0"><a aria-expanded="false" aria-haspopup="true" class="primaryNavMenu__trigger primaryNavMenu__trigger--siteHeaderBrowseMenu" data-reactid=".eynpw4eznk.1.0.3.0.2.0.0" data-ux-click="true" href="/book" role="button"><span data-reactid=".eynpw4eznk.1.0.3.0.2.0.0.0">Browse ▾</span></a><div class="primaryNavMenu__menu gr-box gr-box--withShadowLarge" data-reactid=".eynpw4eznk.1.0.3.0.2.0.1" role="menu"><div class="siteHeader__browseMenuDropdown" data-reactid=".eynpw4eznk.1.0.3.0.2.0.1.0"><ul class="siteHeader__subNav" data-reactid=".eynpw4eznk.1.0.3.0.2.0.1.0.0"><li class="menuLink" data-reactid=".eynpw4eznk.1.0.3.0.2.0.1.0.0.0" role="menuitem"><a class="siteHeader__subNavLink" data-reactid=".eynpw4eznk.1.0.3.0.2.0.1.0.0.0.0" href="/recommendations">Recommendations</a></li><li class="menuLink" data-reactid=".eynpw4eznk.1.0.3.0.2.0.1.0.0.1" role="menuitem"><a class="siteHeader__subNavLink" data-reactid=".eynpw4eznk.1.0.3.0.2.0.1.0.0.1.0" href="/choiceawards">Choice Awards</a></li><li class="menuLink" data-reactid=".eynpw4eznk.1.0.3.0.2.0.1.0.0.2" role="menuitem"><a class="s ...
# </div>
# <div class="siteHeaderBottomSpacer"></div>
# <div class="mainContentContainer">
# <div class="mainContent">
# <div class="mainContentFloat">
# <div id="flashContainer">
# </div>
# <h1>
# <a href="/genres">Genres</a> &gt;
#   Shelves
# </h1>
# <div class="leftContainer">
# <form accept-charset="UTF-8" action="/genres/search" class="exploreSearchForm box greyBox searchBox searchBox--large" method="get" name="shelfSearchForm"><input name="utf8" type="hidden" value="✓"/>
# <input class="searchBox--large__input" id="shelf" name="shelf" placeholder="Find a genre by name" style="width: 508px" type="text"/>
# <input class="gr-button u-marginLeftTiny" type="submit" value="Find Genre"/>
# </form>
# <div class="greyText" style="float: right; margin-right: 20px">
# <form accept-charset="UTF-8" action="/genres/list" id="filterForm" method="get" name="filterForm"><input name="utf8" type="hidden" value="✓"/>
# <span class="greyText smallText">show:</span>
# <select class="smallText" id="filter" name="filter" onchange="document.filterForm.submit();">
# <option selected='"selected"' value="none">All</option>
# <option value="top-level">Top Level Only</option>
# </select>
# </form> </div>
# <br class="clear"/>
# <div class="left" style="width:200px">
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/10th-century">10th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             3,854 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/11th-century">11th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             5,267 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/12th-century">12th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             8,494 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/13th-century">13th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             7,238 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/14th-century">14th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             12,864 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/15th-century">15th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             15,971 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/16th-century">16th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             43,811 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/17th-century">17th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             52,405 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/1864-shenandoah-campaign">1864-shenandoah-campaign</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             35 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/18th-century">18th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             91,348 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/1917">1917</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,368 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/19th-century">19th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             351,127 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/1st-grade">1st-grade</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             53,559 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/20th-century">20th-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             698,641 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/21st-century">21st-century</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             444,165 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/2nd-grade">2nd-grade</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             55,624 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/40k">40k</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             13,524 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/abuse">abuse</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             334,907 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/academia">academia</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             130,138 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/academic">academic</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             310,140 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/academics">academics</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             48,979 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/accounting">accounting</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             4,705 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/accra">accra</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             519 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/action">action</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             695,671 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/activism">activism</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             47,192 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/adaptations">adaptations</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             63,790 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/addis-ababa">addis-ababa</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             56 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/addition">addition</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,740 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/adolescence">adolescence</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             108,385 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/adoption">adoption</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             55,259 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/adult">adult</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             2,390,078 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/adult-colouring-books">adult-colouring-books</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             262 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/adult-fiction">adult-fiction</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,199,991 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/adventure">adventure</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,617,686 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/adventurers">adventurers</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             6,319 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/aeroplanes">aeroplanes</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             708 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/africa">africa</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             220,919 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/african-american">african-american</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             130,088 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/african-american-literature">african-american-literature</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             19,746 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/african-american-romance">african-american-romance</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             11,753 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/african-literature">african-literature</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             24,359 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/agender">agender</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             230 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/agriculture">agriculture</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             17,845 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/aircraft">aircraft</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             2,603 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/airliners">airliners</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             18 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/airships">airships</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             2,184 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/albanian-literature">albanian-literature</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,739 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/alchemy">alchemy</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             22,921 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/alcohol">alcohol</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             19,263 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/alexandria">alexandria</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             15,224 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/algebra">algebra</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             2,117 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/algeria">algeria</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             7,314 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/algiers">algiers</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             966 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/algorithms">algorithms</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             4,784 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/aliens">aliens</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             195,362 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/alternate-history">alternate-history</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             145,690 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/alternate-universe">alternate-universe</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             75,001 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/alternative-medicine">alternative-medicine</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             6,038 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/amateur-sleuth">amateur-sleuth</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             21,108 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/amazon">amazon</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             748,172 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/ambulance-service">ambulance-service</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             8 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/ambulances">ambulances</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             460 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/american">american</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             675,754 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/american-civil-war">american-civil-war</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             29,199 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/american-classics">american-classics</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             76,553 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/american-fiction">american-fiction</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             141,285 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/american-history">american-history</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             268,015 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/american-novels">american-novels</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             38,429 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/american-revolution">american-revolution</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             25,120 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/american-revolutionary-war">american-revolutionary-war</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             2,357 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/americana">americana</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             164,032 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/amish">amish</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             55,227 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/amish-fiction">amish-fiction</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             14,336 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/amish-historical-romance-fiction">amish-historical-romance-fiction</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             912 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/ancient">ancient</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             81,615 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/ancient-history">ancient-history</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             100,537 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/androgyne">androgyne</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,000 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/angels">angels</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             202,383 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/anglo-saxon">anglo-saxon</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             13,268 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/angola">angola</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             2,663 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/animal-fiction">animal-fiction</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             29,657 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/animals">animals</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             606,230 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/anime">anime</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             53,300 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/anthologies">anthologies</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             218,582 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/anthropology">anthropology</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             185,383 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/anthropomorphic">anthropomorphic</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             26,497 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/anti-racist">anti-racist</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,657 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/antietam-campaign">antietam-campaign</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             65 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/antiquities">antiquities</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             6,593 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/antisemitism">antisemitism</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             6,024 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/apocalyptic">apocalyptic</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             129,610 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/apple">apple</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             14,225 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/applied-mathematics">applied-mathematics</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             390 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/appomattox-campaign">appomattox-campaign</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             54 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/archaeology">archaeology</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             51,067 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/architecture">architecture</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             102,666 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/arithmetic">arithmetic</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             747 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/army-of-northern-virginia">army-of-northern-virginia</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             153 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/army-of-tennessee">army-of-tennessee</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             137 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/army-of-the-potomac">army-of-the-potomac</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             125 books
#           </div>
# <div class="clear"></div>
# </div>
# </div>
# <div class="left" style="width:200px">
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/art">art</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             761,051 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/art-and-photography">art-and-photography</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             12,145 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/art-books-monographs">art-books-monographs</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             470 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/art-design">art-design</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             27,152 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/art-history">art-history</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             67,837 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/arthurian">arthurian</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             32,612 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/artificial-intelligence">artificial-intelligence</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             20,189 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/asexual">asexual</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             4,107 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/asia">asia</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             212,306 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/asian-literature">asian-literature</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             50,893 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/asmara">asmara</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             440 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/aspergers">aspergers</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             4,879 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/astrology">astrology</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             25,547 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/astronomy">astronomy</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             36,885 books
#           </div>
# <div class="clear"></div>
# ...
#             4 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cookbooks">cookbooks</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             485,382 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cooking">cooking</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             249,729 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/coptic-language">coptic-language</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             442 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/coptology">coptology</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             94 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/copts">copts</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             543 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/counselling">counselling</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             10,310 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/counter-culture">counter-culture</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             10,200 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/counting">counting</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             17,409 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/couture">couture</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             658 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cozy-mystery">cozy-mystery</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             287,459 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/crafts">crafts</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             71,595 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/crime">crime</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,380,590 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/criticism">criticism</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             164,134 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/crochet">crochet</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             14,473 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cross-dressing">cross-dressing</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             9,412 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cthulhu-mythos">cthulhu-mythos</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             7,764 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cuisine">cuisine</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             8,245 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/culinary">culinary</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             26,951 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cult-classics">cult-classics</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             41,218 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cults">cults</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             21,293 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cultural">cultural</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             330,854 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cultural-heritage">cultural-heritage</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             1,889 books
#           </div>
# <div class="clear"></div>
# </div>
# <div class="shelfStat">
# <div style="float: left; width: 100px;">
# <a class="mediumText actionLinkLite" href="/genres/cultural-studies">cultural-studies</a>
# </div>
# <div class="smallText greyText" style="text-align: right; width: 80px; float: left;">
#             103,134 books
#           </div>
# <div class="clear"></div>
# </div>
# </div>
# <br class="clear"/>
# <div><span class="previous_page disabled">« previous</span> <em class="current">1</em> <a href="/genres/list?page=2" rel="next">2</a> <a href="/genres/list?page=3">3</a> <a href="/genres/list?page=4">4</a> <a href="/genres/list?page=5">5</a> <a class="next_page" href="/genres/list?page=2" rel="next">next »</a></div>
# <br class="clear"/>
# <div class="moreLink">
# <a class="actionLink" href="/shelf">See all shelves...</a>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# <div class="clear"></div>
# </div>
# <div class="clear"></div>
# <footer class="responsiveSiteFooter">
# <div class="responsiveSiteFooter__contents gr-container-fluid">
# <div class="gr-row">
# <div class="gr-col gr-col-md-8 gr-col-lg-6">
# <div class="gr-row">
# <div class="gr-col-md-3 gr-col-lg-4">
# <h3 class="responsiveSiteFooter__heading">Company</h3>
# <ul class="responsiveSiteFooter__linkList">
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/about/us">About us</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/jobs">Careers</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/about/terms">Terms</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/about/privacy">Privacy</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="https://help.goodreads.com">Help</a>
# </li>
# </ul>
# </div>
# <div class="gr-col-md-4 gr-col-lg-4">
# <h3 class="responsiveSiteFooter__heading">Work with us</h3>
# <ul class="responsiveSiteFooter__linkList">
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/author/program">Authors</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/advertisers">Advertise</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/news?content_type=author_blogs">Authors &amp; ads blog</a>
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/api">API</a>
# </li>
# </ul>
# </div>
# <div class="gr-col-md-5 gr-col-lg-4">
# <h3 class="responsiveSiteFooter__heading">Connect</h3>
# <div class="responsiveSiteFooter__socialLinkWrapper">
# <a class="responsiveSiteFooter__socialLink" href="https://www.facebook.com/Goodreads/"><img alt="Goodreads on Facebook" src="https://s.gr-assets.com/assets/site_footer/footer_facebook-ea4ab848f8e86c5f5c98311bc9495a1b.svg"/>
# </a><a class="responsiveSiteFooter__socialLink" href="https://twitter.com/goodreads"><img alt="Goodreads on Twitter" src="https://s.gr-assets.com/assets/site_footer/footer_twitter-126b3ee80481a763f7fccb06ca03053c.svg"/>
# </a></div>
# <div class="responsiveSiteFooter__socialLinkWrapper">
# <a class="responsiveSiteFooter__socialLink" href="https://www.instagram.com/goodreads/"><img alt="Goodreads on Instagram" src="https://s.gr-assets.com/assets/site_footer/footer_instagram-d59e3887020f12bcdb12e6c539579d85.svg"/>
# </a><a class="responsiveSiteFooter__socialLink" href="https://www.linkedin.com/company/goodreads-com/"><img alt="Goodreads on LinkedIn" src="https://s.gr-assets.com/assets/site_footer/footer_linkedin-5b820f4703eff965672594ef4d10e33c.svg"/>
# </a></div>
# </div>
# </div>
# </div>
# <div class="gr-col gr-col-md-4 gr-col-lg-6 responsiveSiteFooter__appLinksColumn">
# <div class="responsiveSiteFooter__appLinksColumnContents">
# <div class="responsiveSiteFooter__appLinksColumnBadges">
# <a href="https://itunes.apple.com/app/apple-store/id355833469?pt=325668&amp;ct=mw_footer&amp;mt=8"><img alt="Download app for iOS" src="https://s.gr-assets.com/assets/app/badge-ios-desktop-homepage-6ac7ae16eabce57f6c855361656a7540.svg"/>
# </a><a href="https://play.google.com/store/apps/details?id=com.goodreads&amp;utm_source=mw_footer&amp;pcampaignid=MKT-Other-global-all-co-prtnr-py-PartBadge-Mar2515-1"><img alt="Download app for Android" src="https://s.gr-assets.com/assets/app/badge-android-desktop-home-0f517cbae4d56c88a128d27a7bea1118.png" srcset="https://s.gr-assets.com/assets/app/badge-android-desktop-home-2x-e31514e1fb4dddecf9293aa526a64cfe.png 2x"/>
# </a></div>
# <ul class="responsiveSiteFooter__linkList">
# <li class="responsiveSiteFooter__linkListItem">
# ©
# 2019
# Goodreads, Inc.
# </li>
# <li class="responsiveSiteFooter__linkListItem">
# <a class="responsiveSiteFooter__link" href="/toggle_mobile">Mobile version
# </a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <div data-react-class="ReactComponents.LoginInterstitial" data-react-props='{"allowFacebookSignIn":true,"allowAmazonSignIn":true,"path":{"signInUrl":"/user/sign_in","signUpUrl":"/user/sign_up","privacyUrl":"/about/privacy","termsUrl":"/about/terms","thirdPartyRedirectUrl":"/user/new?connect_prompt=true"}}'><noscript data-react-checksum="-1303506689" data-reactid=".1pe4vb14r9c"></noscript></div>
# <div id="overlay" onclick="Lightbox.hideBox()" style="display:none"></div>
# <div id="box" style="display:none">
# <div class="xBackground js-closeModalIcon" id="close" onclick="Lightbox.hideBox()" title="Close this window"></div>
# <div id="boxContents"></div>
# <div id="boxContentsLeftovers" style="display:none"></div>
# <div class="clear"></div>
# </div>
# <div id="fbSigninNotification" style="display:none;">
# <p>Welcome back. Just a moment while we sign you in to your Goodreads account.</p>
# <img alt="Login animation" src="https://s.gr-assets.com/assets/facebook/login_animation-085464711e6c1ed5ba287a2f40ba3343.gif"/>
# </div>
# <script>
#   //<![CDATA[
#     qcdata = {} || qcdata;
#       (function(){
#         var elem = document.createElement('script');
#         elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://pixel") + ".quantserve.com/aquant.js?a=p-0dUe_kJAjvkoY";
#         elem.async = true;
#         elem.type = "text/javascript";
#         var scpt = document.getElementsByTagName('script')[0];
#         scpt.parentNode.insertBefore(elem,scpt);
#       }());
#     var qcdata = {qacct: 'p-0dUe_kJAjvkoY', uid: ''};
#   //]]>
# </script>
# <noscript>
# <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-0dUe_kJAjvkoY.gif" style="display: none;" width="1"/>
# </noscript>
# <script>
#   //<![CDATA[
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "6035830", c3: "", c4: "", c5: "", c6: "", c15: ""});
#     (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#     })();
#   //]]>
# </script>
# <noscript>
# <img alt="" height="0" src="https://sb.scorecardresearch.com/p?c1=2&amp;amp;c2=6035830&amp;amp;c3=&amp;amp;c4=&amp;amp;c5=&amp;amp;c6=&amp;amp;c15=&amp;amp;cv=2.0&amp;amp;cj=1" style="display: none" width="0"/>
# </noscript>
# <script>
#   //<![CDATA[
#     window.addEventListener("DOMContentLoaded", function() {
#         ReactStores.NotificationsStore.updateWith({});
#       ReactStores.CurrentUserStore.initializeWith({"currentUser":null});
#       ReactStores.FavoriteGenresStore.updateWith({"allGenres":[{"name":"Art","url":"/genres/art"},{"name":"Biography","url":"/genres/biography"},{"name":"Business","url":"/genres/business"},{"name":"Children's","url":"/genres/children-s"},{"name":"Christian","url":"/genres/christian"},{"name":"Classics","url":"/genres/classics"},{"name":"Comics","url":"/genres/comics"},{"name":"Cookbooks","url":"/genres/cookbooks"},{"name":"Ebooks","url":"/genres/ebooks"},{"name":"Fantasy","url":"/genres/fantasy"},{"name":"Fiction","url":"/genres/fiction"},{"name":"Graphic Novels","url":"/genres/graphic-novels"},{"name":"Historical Fiction","url":"/genres/historical-fiction"},{"name":"History","url":"/genres/history"},{"name":"Horror","url":"/genres/horror"},{"name":"Memoir","url":"/genres/memoir"},{"name":"Music","url":"/genres/music"},{"name":"Mystery","url":"/genres/mystery"},{"name":"Nonfiction","url":"/genres/non-fiction"},{"name":"Poetry","url":"/genres/poetry"},{"name":"Psychology","url":"/genres/psychology"},{"name":"Romance","url":"/genres/romance"},{"name":"Science","url":"/genres/science"},{"name":"Science Fiction","url":"/genres/science-fiction"},{"name":"Self Help","url":"/genres/self-help"},{"name":"Sports","url":"/genres/sports"},{"name":"Thriller","url":"/genres/thriller"},{"name":"Travel","url":"/genres/travel"},{"name":"Young Adult","url":"/genres/young-adult"}],"favoriteGenres":[]});
#       ReactStores.TabsStore.updateWith({"communitySpotlight":"groups"});
#
#     });
#   //]]>
# </script>
# </body>
# </html>
# <!-- This is a random-length HTML comment: ... -->

# %%
genreList = []
for soup in [soup1, soup2, soup3, soup4, soup5]:
    for a in soup.find_all('a', href = re.compile("/genres/")): 
        if a.text: 
            genreList.append(a['href'].split("/", 2)[2])

# %%
genreList[0:10]
# Out:
# ['art',
#  'biography',
#  'business',
#  'children-s',
#  'christian',
#  'classics',
#  'comics',
#  'cookbooks',
#  'ebooks',
#  'fantasy']

# %%
len(genreList)
# Out:
# 1553

# %%
genres = pd.DataFrame(genreList).drop_duplicates(0)

# %%
genres.columns = ['tag_name']

# %%
genres
# Out:
#                             tag_name
# 0                                art
# 1                          biography
# 2                           business
# 3                         children-s
# 4                          christian
# 5                           classics
# 6                             comics
# 7                          cookbooks
# 8                             ebooks
# 9                            fantasy
# 10                           fiction
# 11                    graphic-novels
# 12                historical-fiction
# 13                           history
# 14                            horror
# 15                            memoir
# 16                             music
# 17                           mystery
# 18                       non-fiction
# 19                            poetry
# 20                        psychology
# 21                           romance
# 22                           science
# 23                   science-fiction
# 24                         self-help
# 25                            sports
# 26                          thriller
# 27                            travel
# 28                       young-adult
# 58                      10th-century
# ...                              ...
# 1517        women-and-gender-studies
# 1518                          womens
# 1519                  womens-fiction
# 1520                   womens-rights
# 1521                  womens-studies
# 1522                    wonder-woman
# 1523                        woodwork
# 1524                           words
# 1525                   world-history
# 1526               world-of-darkness
# 1527               world-of-warcraft
# 1528                     world-war-i
# 1529                    world-war-ii
# 1530                         writing
# 1531            wwii-related-fiction
# 1532                           x-men
# 1533                            yaoi
# 1535        young-adult-contemporary
# 1536             young-adult-fantasy
# 1537  young-adult-historical-fiction
# 1538          young-adult-paranormal
# 1539             young-adult-romance
# 1540     young-adult-science-fiction
# 1541                   young-readers
# 1542                            yuri
# 1543                          zambia
# 1544                             zen
# 1545                        zimbabwe
# 1546                         zombies
# 1547              %E6%BC%AB%E7%94%BB
#
# [1242 rows x 1 columns]

# %%
genres.to_csv('genres.csv')
